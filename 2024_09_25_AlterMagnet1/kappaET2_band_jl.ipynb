# %% [markdown]
# # $\kappa$(ET)$_2$-X の強束縛模型でのバンド計算

# %% [markdown]
# $\kappa$(ET)$_2$-X を強束縛模型で計算する。
# この結晶は2次元的に扱うことができ、単位胞は$x$軸の格子定数を$a$, $y$軸の格子定数を$b$とした長方形である。

# %% [markdown]
# この系のハミルトニアンは2次元ハバード模型
#
# $$
# \mathcal{H} = \sum_{ij}t_{ij}(c_i^{\dagger}c_j+\text{h.c.})+U\sum_i n_{\uparrow} n_{\downarrow}
# $$
# をもとにしたものを使う。この和の添え字はサイトを表している。
# これを$\kappa$型の格子に応用したのが
# $$
#     \mathcal{H}_{\kappa}
#     = U \sum_{i\mu} n_{i\mu\uparrow}n_{i\mu\downarrow}
#     + t_a\sum_{i\sigma}(c_{ia\sigma}^\dagger c_{ib\sigma} + \text{h.c})
#     +\sum_{\langle ij \rangle \mu\mu'\sigma}
#         t_{ij}^{\mu\mu'}(c_{i\mu\sigma}^\dagger c_{j\mu'\sigma} +\text{h.c.})
# $$
# である。
#
# ここでの添え字は
#  i 番目のダイマー にある
# $ \sigma = \uparrow, \downarrow $(スピン),
# $\mu = a,b $(分子内のサイト)
# といった意味である。
#
# すると第二項はダイマー内のホッピングを表していて、

# %% [markdown]
# ここでのパラメータは
#
# https://doi.org/10.1038/s41467-019-12229-y
#
# を参考にすると
#
# $$
# \begin{align*}
#     t_{a} &= -0.207 \,\text{eV}\\
#     t_{p} &= -0.102 \,\text{eV}\\
#     t_{q} &= -0.043 \,\text{eV}\\
#     t_{b} &= -0.067 \,\text{eV}\\
#     U     &= 1      \,\text{eV}
# \end{align*}
# $$
#
# というようにすればよいようである。

# %% [markdown]
# 解くために平均場近似をする。
# そうすると相互作用項はハートリー項とフォック項に分けられて
# $$
# \begin{align}
#     n_{\uparrow} n_{\downarrow}
#         &= c_{\uparrow}^\dagger c_{\uparrow} c_{\downarrow}^\dagger c_{\downarrow} \\
#         &= \Big(
#             \langle n_{\uparrow} \rangle c_{\downarrow}^\dagger c_{\downarrow}
#             + c_{\uparrow}^\dagger c_{\uparrow} \langle n_{\downarrow} \rangle
#             -\langle n_{\uparrow} \rangle\langle n_{\downarrow} \rangle
#         \Big)
#         - \Big(
#             \langle c_{\downarrow}^\dagger c_{\uparrow} \rangle c_{\uparrow}^\dagger c_{\downarrow}
#             +\langle c_{\uparrow}^\dagger c_{\downarrow} \rangle c_{\downarrow}^\dagger c_{\uparrow}
#             -\langle c_{\downarrow}^\dagger c_{\uparrow} \rangle \langle c_{\uparrow}^\dagger c_{\downarrow} \rangle
#         \Big)
# \end{align}
# $$
# と書け、粒子数の期待値は単位胞に電子が6個入るように
# $$
#  \braket{n_\uparrow} = \braket{n_\downarrow} = 0.75
# $$
# としてやればよい。
# そして、
# $$
#  m \equiv e^{i\theta} = \langle c_{\uparrow}^\dagger c_{\downarrow} \rangle, \quad m^* = e^{-i\theta} = \langle c_{\downarrow}^\dagger c_{\uparrow} \rangle
# $$
# はセルフコンシステントに解くらしい。
# また簡単のため長方形ではなく格子定数が 1 正方形として計算する?

# %% [markdown]
# ただ、これはもとのハバードハミルトニアンのホッピングを丁寧に書き下しただけのように見える。
# のでいったん普通のハバードハミルトニアンをいじっていく。
#
# このハバードハミルトニアンをフーリエ変換する。
# 生成消滅演算子はフーリエ変換すると
# $$
#     c_i = \frac{1}{\sqrt{N}}\sum_{\bm{k}} c_{i\bm{k}} e^{i\bm{k}\cdot\bm{R}_i}, \qquad c_i^\dagger = \frac{1}{\sqrt{N}}\sum_{\bm{k}} c_{i\bm{k}}^\dagger e^{-i\bm{k} \cdot \bm{R}_i}
# $$
# より、
# $$
#     \mathcal{H} =\sum_{\bm{k}}\left\{ \sum_{ij} (t_{ij} e^{i\bm{k}\cdot(\bm{R}_j-\bm{R}_i)} c_{i\bm{k}}^\dagger c_{j\bm{k}} + \text{h.c.}) +  \langle n \rangle U\sum_{i} (c_{i\bm{k}\uparrow}^\dagger c_{i\bm{k}\uparrow}+c_{i\bm{k}\downarrow}^\dagger c_{i\bm{k}\downarrow}-\langle n \rangle)
#     - m U \sum_{i} (c_{i\bm{k}\uparrow}^\dagger c_{i\bm{k}\downarrow}+c_{i\bm{k}\downarrow}^\dagger c_{i\bm{k}\uparrow}-m)
#     \right\}
# $$
# 各波数ごとにブロック対角化できた。

# %% [markdown]
# サイトを表す添え字 $ i=0,1, \dots, 7 $ をこのようにする。
#
# $ i = 0 $ Aダイマーの1番目のサイトにあるスピンアップの軌道
#
# $ i = 1 $ Aダイマーの2番目のサイトにあるスピンアップの軌道
#
# $ i = 2 $ Bダイマーの1番目のサイトにあるスピンアップの軌道
#
# $ i = 3 $ Bダイマーの2番目のサイトにあるスピンアップの軌道
#
# $ i = 4 $ Aダイマーの1番目のサイトにあるスピンダウンの軌道
#
# $ i = 5 $ Aダイマーの2番目のサイトにあるスピンダウンの軌道
#
# $ i = 6 $ Bダイマーの1番目のサイトにあるスピンダウンの軌道
#
# $ i = 7 $ Bダイマーの2番目のサイトにあるスピンダウンの軌道

# %% [markdown]
# これより対角化すべきハミルトニアン行列は
# $$
#  \begin{pmatrix}
#     \langle n \rangle U &  t_a + t_b e^{ik_x} & t_p(1+e^{-ik_y}) & t_q e^{-ik_y}(1+e^{-ik_x})           & -mU & 0 & 0 & 0\\
#     t_a + t_b e^{-ik_x}  & \langle n \rangle U & t_p (1+e^{-ik_x}) & t_q e^{-ik_x}(1+e^{-ik_y})         & 0 & -mU & 0 &0\\
#     t_p(1+e^{ik_y}) & t_p(1+e^{ik_x}) & \langle n \rangle U & t_a + t_b e^{-ik_x}                       & 0 & 0 &-mU & 0\\
#     t_q e^{ik_y}(1+e^{ik_x}) & t_q e^{ik_x}(1+e^{ik_y}) & t_a + t_b e^{ik_x} & \langle n \rangle U      & 0 & 0 & 0 & -mU\\
#
#     -m^*U & 0 & 0 & 0   & \langle n \rangle U &  t_a + t_b e^{ik_x} & t_p(1+e^{-ik_y}) & t_q e^{-ik_y}(1+e^{-ik_x})\\
#     0 & -m^*U & 0 & 0   & t_a + t_b e^{-ik_x}  & \langle n \rangle U & t_p (1+e^{-ik_x}) & t_q e^{-ik_x}(1+e^{-ik_y})\\
#     0 & 0 &-m^*U & 0    & t_p(1+e^{ik_y}) & t_p(1+e^{ik_x}) & \langle n \rangle U & t_a + t_b e^{-ik_x} \\
#     0 & 0 & 0 & -m^*U   & t_q e^{ik_y}(1+e^{ik_x}) & t_q e^{ik_x}(1+e^{ik_y}) & t_a + t_b e^{ik_x} & \langle n \rangle U
#  \end{pmatrix}
# $$
# となるように思われる。

# %% [markdown]
# セルフコンシステントに解くやり方がわからないのでまずは m=0 として無駄に 8x8 行列の固有値を求めてみる。

# %%
using LinearAlgebra
using Plots

# %% [markdown]
# ハミルトニアンの定義

# %%
function ene(kx, ky, U = 1.0, n=0.75, θ=0.0)
    m = exp(im * θ)
    ta = -0.207
    tb = -0.067
    tp = -0.102
    tq = 0.043
    H = zeros(Complex{Float64}, (8,8))
    H[1,1] = n*U
    H[1,2] = ta + tb * exp(im*kx)
    H[1,3] = tb * (1 + exp(im*kx))
    H[1,4] = tq * exp(-im*ky) * (1 + exp(-im*kx))
    H[1,5] = -m*U

    H[2,2] = n*U
    H[2,3] = tp * (1 + exp(-im*kx))
    H[2,4] = tq * exp(-im*kx) * (1 + exp(-im*ky))
    H[2,6] = -m*U

    H[3,3] = n*U
    H[3,4] = ta + tb*exp(-im*kx)
    H[3,7] = -m*U

    H[4,4] = n*U
    H[4,8] =-m*U

    H[5,5] = H[1,1]
    H[5,6] = H[1,2]
    H[5,7] = H[1,3]
    H[5,8] = H[1,4]

    H[6,6] = H[2,2]
    H[6,7] = H[2,3]
    H[6,8] = H[2,4]

    H[7,7] = H[3,3]
    H[7,8] = H[3,4]

    H[8,8] = H[4,4]
    for i in 1:8
        for j in 1:i-1
            H[i,j] = conj(H[j,i])
        end
    end
    return eigen(H).values
end
# Out:
# ene (generic function with 4 methods)

# %% [markdown]
# k 点パスを生成する関数

# %%
function gen_kpath(k_points, path::Vector{Tuple{String,String}} , npoints = 50)
    k_path = []
    labels = []
    distances = []
    total_distance = 0.0
    for (spoint, epoint) in path
        k_start = k_points[spoint]
        k_end   = k_points[epoint]
        # 線形補完でnpoints個のk点の生成
        segment = LinRange(k_start, k_end, npoints)
        append!(k_path, segment)
        # 各セグメントの最初の点にラベルを付ける
        append!(labels, [spoint; fill(nothing, npoints - 1)])
        # プロットの横軸のための距離
        segment_dist = range(total_distance, length=npoints, stop=total_distance + norm(k_end - k_start,2))
        append!(distances, segment_dist)
        total_distance += norm(k_start - k_end,2)
    end
    return (k_path, labels, distances)
end
# Out:
# gen_kpath (generic function with 2 methods)

# %% [markdown]
# 通る経路は
# $$
#  \Gamma (0,0)
#  \rightarrow Y(0,1/2)
#  \rightarrow M'(-1/2,1/2)
#  \rightarrow \Sigma'(-1/4,1/4)
#  \rightarrow \Gamma(0,0)
#  \rightarrow \Sigma(1/4,1/4)
#  \rightarrow M(1/2,1/2)
#  \rightarrow X(1/2, 0)
#  \rightarrow \Gamma(0,0)
# $$
# である。

# %% [markdown]
# まずは点の名前と座標の定義

# %%
k_points = Dict()

k_points["Γ"]    = [0.0, 0.0]
k_points["X"]    = [π, 0.0]
k_points["Y"]    = [0.0, π]
k_points["M"]    = [π, π]
k_points["Σ"]    = [π/2, π/2]
k_points["M'"]   = [-π, π]
k_points["Σ'"]   = [-π/2, π/2]
# Out:
# 2-element Vector{Float64}:
#  -1.5707963267948966
#   1.5707963267948966

# %% [markdown]
# path の設定

# %%
path = [("Γ", "Y"), ("Y", "M'"), ("M'", "Σ'"), ("Σ'","Γ"), ("Γ", "Σ"), ("Σ", "M"), ("M", "X"), ("X", "Γ")]
# Out:
# 8-element Vector{Tuple{String, String}}:
#  ("Γ", "Y")
#  ("Y", "M'")
#  ("M'", "Σ'")
#  ("Σ'", "Γ")
#  ("Γ", "Σ")
#  ("Σ", "M")
#  ("M", "X")
#  ("X", "Γ")

# %%
(k_path, label, distances) = gen_kpath(k_points, path)
# Out:
# (Any[[0.0, 0.0], [0.0, 0.0641141357875468], [0.0, 0.1282282715750936], [0.0, 0.19234240736264038], [0.0, 0.2564565431501872], [0.0, 0.320570678937734], [0.0, 0.38468481472528077], [0.0, 0.4487989505128276], [0.0, 0.5129130863003744], [0.0, 0.5770272220879212]  …  [0.5770272220879211, 0.0], [0.5129130863003742, 0.0], [0.44879895051282775, 0.0], [0.3846848147252809, 0.0], [0.320570678937734, 0.0], [0.2564565431501871, 0.0], [0.19234240736264027, 0.0], [0.12822827157509373, 0.0], [0.06411413578754686, 0.0], [0.0, 0.0]], Any["Γ", nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing  …  nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing], Any[0.0, 0.0641141357875468, 0.1282282715750936, 0.19234240736264038, 0.2564565431501872, 0.320570678937734, 0.38468481472528077, 0.4487989505128276, 0.5129130863003744, 0.5770272220879212  …  20.875109268587984, 20.93922340437553, 21.003337540163077, 21.067451675950625, 21.13156581173817, 21.19567994752572, 21.259794083313263, 21.32390821910081, 21.388022354888356, 21.452136490675905])

# %%
kx_path = []
ky_path = []
for (kx, ky) in k_path
    append!(kx_path, kx)
    append!(ky_path, ky)
end
plot(kx_path, ky_path)

# %% [markdown]
# プロット

# %% [markdown]
# バンドの計算

# %%
band = []
for i in 1:size(k_path)[1]
    append!(band, ene(k_path[i][1], k_path[i][2], 0.0))
end
scatter(band))
# Out:
# UndefVarError: `plt` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[37]:6

# %%
band = []
for i in 1:size(k_path)[1]
    append!(band, ene(k_path[i][1], k_path[i][2], 1, 0.8, π/2))
end
scatter(band)
