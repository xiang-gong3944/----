# %% [markdown]
# ## 銅酸化物様結晶と交代磁性

# %% [markdown]
# ## 考える系の状況

# %% [markdown]
# ### ハミルトニアン

# %% [markdown]
# 交代磁性についての Smejkal-Sinova の Phys.Rev.X 12040501 にある Ru2 の模式図を見ると、
# 銅酸化物の二次元正方格子を歪ませたように見える。
# なので Toy model として銅酸化物をひずませた模型を作って、
# 交代磁性が出るかを確認してみるというアイデアが出てもおかしくはない。
# しかし、遠山先生曰くなぜかやった結果というのが出回っていないらしい。
#
# はじめ単なる模型かと思いきや、層状の結合を忘れれば、CuF2 がその形結晶構造となっている。
# なので CuF2 の交代磁性を調べてみたというものになる。
#
# なのでこのモデルを調べて、相図やスピン伝導度、最終的には超伝導との関連も見たいといった目標である。

# %% [markdown]
# 一般的な銅酸化物をモデルとした模型のハミルトニアンは次のように書ける。
# $$
# \begin{align*}
#     \mathcal{H}
#         &= \mathcal{H}_\varepsilon + \mathcal{H}_U + \mathcal{H}_T\\
#     \mathcal{H}_\varepsilon
#         &= \varepsilon_d \sum_{i,\sigma} n_{i,\sigma}^d + (\varepsilon_d +\Delta)\sum_{i,\delta,\sigma}n_{i+\delta/2,\sigma}^p \\
#     \mathcal{H}_U
#         &= U_d \sum_i n_{i,\uparrow}^d n_{i,\downarrow}^d
#             + U_p \sum_{i,\delta}n_{i+\delta/2,\uparrow}^p n_{i+\delta/2,\downarrow}^p
#             + U_{pd} \sum_{i,\delta,\sigma,\sigma'}n_{i,\sigma}^d n_{i+\delta/2,\sigma'}^p \\
#     \mathcal{H}_T
#         &= \sum_{i,\sigma}\Bigg[
#             T_{pd}d_{i,\sigma}^\dagger\left(
#                 p_{i+y/2,\sigma}-p_{i+x/2,\sigma}-p_{i-y/2,\sigma}+p_{i+x/2,\sigma}
#             \right)\\&\qquad
#             +T_{pp}\left(
#                 p_{i+y/2,\sigma}^\dagger p_{i+x/2,\sigma} - p_{i-x/2,\sigma}^\dagger p_{i+y/2,\sigma}
#                 + p_{i-y/2,\sigma}^\dagger p_{i-x/2,\sigma} - p_{i+x/2,\sigma}^\dagger p_{i-y/2,\sigma}
#             \right)
#             + \text{h.c.}
#         \Bigg].
# \end{align*}
# $$
# ここで、
#
# - $d_{i,\sigma}$: サイト $i$ にある $3d_{x^2-y^2}$ 軌道のスピン $\sigma$ のホールの消滅演算子
# - $n_{i,\sigma}^d$: はその数演算子
# - $p_{i\pm x(y)/2,\sigma}$: 銅イオンを $x(y)$ 方向につなぐサイト $i\pm x(y)/2$ にある $2p_x(2p_y)$ 軌道のスピン $\sigma$ のホールの消滅演算子
# - $n_{i\pm\delta/2,\sigma}^p$: その数演算子。
#
# である。
#
# ホッピングの符号はホールのホッピングになっていることから、
# 軌道の位相が同じ時には $T>0$, そうでないときには$T<0$である。

# %% [markdown]
# ![lattice_structure.png](attachment:lattice_structure.png)

# %% [markdown]
# Slater-Koster table をよりホッピングの値は方向余弦$(l,m,n)$を用いて
# $$
# \begin{align*}
#     T_{pp} &= lmV_{pp\sigma}-lmV_{pp\pi} = \frac{2a(1-a)}{a^2+(1-a)^2}\frac{V_{pp\sigma}-V_{pp\pi}}{2}= \frac{2a(1-a)}{a^2+(1-a)^2}T_{pp0}\\
#     T_{pd} &= \frac{\sqrt{3}}{2}l(l^2-m^2)V_{pd\sigma}+l(1-l^2+m^2)V_{pd\pi} = \frac{\sqrt{3}}{2}V_{pd\sigma} = T_{pd0}
# \end{align*}
# $$
# となる。
# ここで $a$ は Cu と O の距離であり、これを変えたときの秩序変数を見たいので明記している。
# また、$T_{pd}$ の $a$ 依存性を入れてみたいが、思いつかないので同じものであるとする。

# %% [markdown]
# A. K. McMahan, Prichar M. Martin, S.Satpathy (PhysRevB 386650 1988) に乗ってる Slater-Koster パラメータはこんな感じ
# $$
# \begin{align*}
#     V_{pp\sigma} &= 1.0 \,\text{eV}\\
#     V_{pp\pi} &= -0.3\,\text{eV}\\
#     V_{pd\sigma} &= -1.85\,\text{eV}\\
#     V_{pd\pi} &= -1.85\,\text{eV}\\
#     U_d &= 8.5 \,\text{eV}\\
#     U_p &= 4.1\,\text{eV} \sim 7.3 \,\text{eV}\\
#     U_{pd} &= 0.6\,\text{eV} \sim 1.3 \,\text{eV}\\
#     \Delta = E_p - E_d &= 3.0\,\text{eV}
# \end{align*}
# $$

# %% [markdown]
# また、 Physics of Transition of Metal Oxides の中にあるパラメータだと、
# $$
# \begin{align*}
#     U_d &= 8\\
#     U_p &= 4\\
#     U_{pd} &= 1\\
#     \Delta = E_p-E_d &= 3\\
#     T_{pd} &= 1\\
#     T_{pp} &= 0.5
# \end{align*}
# $$
# となっている。
# また、注意したいのが波動関数の位相によるホッピングの符号の違いがあるというのにも気を付けたい

# %% [markdown]
# 平均場で使うクーロン相互の形は
# $$
#     \mathcal{H}_C =  U_d \sum_{k}\frac{1}{2}m(n_{k\downarrow}^d-n_{k\uparrow}^d)
# $$

# %% [markdown]
# $$
#     m = \braket{n_{\uparrow}^d}-\braket{n_{\downarrow}^d}
# $$

# %% [markdown]
# とりあえず $U_p=0,\,U_{pd}=0$というようにこの相互作用を無視してやってみる。
# また、酸素の位置は変わらずホッピングだけが変わらないものとして、
# 格子定数は元の二倍を基準とする。
# パラメータを
# $$
# \begin{align*}
#     U_d &= 8\\
#     T_{pp0} &= \frac{V_{pp\sigma}-V_{pp\pi}}{2} =  \frac{1+0.6}{2}\\
#     T_{pd0} &=  \frac{\sqrt{3}}{2}V_{pd\sigma} = \frac{\sqrt{3}}{2} \times 1.85\\
#     E_p &= 3.0\\
#     n_p &= 2.0\\
#     T_{pp} &= \frac{2a(1-a)}{a^2+(1-a)^2}T_{pp0}\\
#     T_{pd1} &= T_{pd0} \times 1.1 \\
#     T_{pd2} &= T_{pd0} \times 0.9
# \end{align*}
# $$
# とする。ここで$T_{pd1},T_{pd2}$は銅と酸素の距離が2種類あるのでそれぞれに対応するホッピング、
# $n_p$ は単位胞内のホールの数で、単位胞内にある2つの銅イオンが持っているとした。
# ハミルトニアン行列は

# %% [markdown]
# $$
# \mathcal{H}(k, a,\pm\sigma) = \begin{pmatrix}
# \mp U_d \delta/2 & 0 & T_{pd1}e^{i(-k_x+k_y)a/2} & T_{pd2} e^{i(k_x+k_y)(1-a)/2} & T_{pd1}e^{i(k_x-k_y)a/2} & T_{pd2}e^{-i(k_x+k_y)(1-a)/2}\\
# & \pm U_d\delta/2 & T_{pd2}e^{i(k_x-k_y)(1-a)/2} & T_{pd1} e^{-i(k_x+k_y)a/2} & T_{pd2}e^{i(-k_x+k_y)(1-a)/2} & T_{pd1}e^{i(k_x+k_y)a/2}\\
# & & E_p & -2T_{pp}\cos\frac{k_x}{2}e^{ik_y(1-2a)/2} & 0 & -2T_{pp}\cos\frac{k_y}{2}e^{-ik_x(1-2a)/2} \\
# & & & E_p & -2T_{pp}\cos\frac{k_y}{2}e^{-ik_x(1-2a)/2} & 0\\
# & & & & E_p & -2T_{pp}\cos\frac{k_x}{2}e^{-ik_y(1-2a)/2}\\
# & & & & &E_p
# \end{pmatrix}
# $$

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from lib import funcs as fs
from lib import post
import time
import os

# %%
def make_delta_graph(x, y, a):
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.set_xlim(2,10)
    # ax1.set_yscale("log")
    ax1.set_title("a = {:02d}".format(int(a*100)))
    ax1.set_xlabel("Np")
    ax1.set_ylabel("delta")
    ax1.plot(x, y + 1e-7)

    path = f"../image/xt/"
    if not os.path.isdir(path):
        os.makedirs(path)
    # 出力
    save_folder = "./output/phase/"
    if not os.path.isdir(save_folder):
        os.makedirs(save_folder)
    image_path = save_folder+"a{:02d}.png".format(int(a*100))
    plt.savefig(image_path)

    return image_path

# %%
model = fs.CuO2()
model.calc_scf()
model.plot_scf()
model.plot_nsite()
model.calc_nscf()
model.plot_dos()
model.plot_band()
model.plot3d_band()

# %%
model = fs.CuO2(5.0, 0.5, 51)
model.calc_scf()
model.calc_nscf()
model.plot_band()
model.plot_fermi_surface()
# Out:
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 42, delta = 5.27e-01
#
# NSCF calculation start.
# NSCF calculation finished.

# %%
model = fs.CuO2(5.0, 0.45, 51)
model.calc_scf()
model.calc_nscf()
model.plot_band()
model.plot_fermi_surface()
# Out:
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 30, delta = 5.14e-01
#
# NSCF calculation start.
# NSCF calculation finished.

# %%
model = fs.CuO2(2.0, 0, 51)
model.calc_scf()
model.plot_scf()
model.plot_nsite()
model.plot_band()
# Out:
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop =  9, delta = 7.80e-01

# %%
np.linspace(2.0, 10.0, 33)
# Out:
# array([ 2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,  4.  ,
#         4.25,  4.5 ,  4.75,  5.  ,  5.25,  5.5 ,  5.75,  6.  ,  6.25,
#         6.5 ,  6.75,  7.  ,  7.25,  7.5 ,  7.75,  8.  ,  8.25,  8.5 ,
#         8.75,  9.  ,  9.25,  9.5 ,  9.75, 10.  ])

# %%
deltas = np.array([])
Nps =  np.linspace(2.0, 10.0, 33)
for Np in Nps:
    model = fs.CuO2(Ne = Np, a = 0, k_mesh = 51)
    model.calc_scf()
    deltas = np.append(deltas, model.delta)
path = make_delta_graph(Nps, deltas, 0)
post.image(f"a = {0:.2f} での delta の計算が終わりました。", path)
# Out:
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop =  9, delta = 7.80e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# Calculation didn't converge. err > 1.0e-06, Ne = 2.25 loop = 1200, delta = 4.24e-01
# latter deltas are [0.16148115 0.06090723 0.34573868]
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# Calculation didn't converge. err > 1.0e-06, Ne = 2.50 loop = 1200, delta = 4.24e-01
# latter deltas are [0.16148115 0.06090723 0.34573868]
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# Calculation didn't converge. err > 1.0e-06, Ne = 2.75 loop = 1200, delta = 4.24e-01
# latter deltas are [0.16148115 0.06090723 0.34573868]
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# Calculation didn't converge. err > 1.0e-06, Ne = 3.00 loop = 1200, delta = 4.24e-01
# latter deltas are [0.16148115 0.06090723 0.34573868]
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# SCF loop converged.  Ne = 6.75, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 15, delta = 4.86e-09
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop =  9, delta = 2.40e-01
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop =  9, delta = 2.40e-01
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop =  9, delta = 2.40e-01
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop = 798, delta = 2.40e-01
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop =  9, delta = 4.30e-01
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop =  9, delta = 4.30e-01
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop =  9, delta = 4.30e-01
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop =  9, delta = 4.30e-01
#
# sent message. HTTP Response:200

# %%
for _a in [0.50, 0.45, 0.40, 0.35, 0.30, 0.25, 0.20, 0.15, 0.10, 0.05, 0.00]:
    deltas = np.array([])
    Nps =  np.linspace(2.0, 10.0, 33)
    for Np in Nps:
        model = fs.CuO2(Ne = Np, a = _a, k_mesh = 51)
        model.calc_scf()
        deltas = np.append(deltas, model.delta)
    path = make_delta_graph(Nps, deltas, _a)
    post.image(f"a = {_a:.3f} での delta の計算が終わりました。", path)
# Out:
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop = 30, delta = 4.56e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# SCF loop converged.  Ne = 2.25, err < 1.0e-06, loop = 60, delta = 3.68e-01
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# SCF loop converged.  Ne = 2.50, err < 1.0e-06, loop = 45, delta = 2.81e-01
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# SCF loop converged.  Ne = 2.75, err < 1.0e-06, loop = 114, delta = 1.66e-01
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# SCF loop converged.  Ne = 3.00, err < 1.0e-06, loop = 30, delta = 6.90e-05
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 36, delta = 3.82e-05
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 30, delta = 5.12e-05
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 126, delta = 2.66e-05
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 24, delta = 4.31e-08
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 33, delta = 2.79e-01
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop = 33, delta = 4.05e-01
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 48, delta = 4.80e-01
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 141, delta = 5.27e-01
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop = 24, delta = 5.57e-01
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop = 45, delta = 5.75e-01
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 42, delta = 5.84e-01
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# e:\Documents\codes\TUS\B3\レポート\2024_11_28_AlterMagnet2\lib\funcs.py:280: RuntimeWarning: invalid value encountered in scalar divide
#   # 収束すると分母が0になり発散するため例外処理が必要
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 18, delta = 5.87e-01
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 18, delta = 5.87e-01
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 24, delta = 5.81e-01
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# SCF loop converged.  Ne = 6.75, err < 1.0e-06, loop = 30, delta = 5.66e-01
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 24, delta = 5.37e-01
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop = 24, delta = 4.78e-01
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 48, delta = 3.33e-01
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 45, delta = 1.88e-01
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 228, delta = 2.89e-02
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop = 21, delta = 2.71e-06
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop = 12, delta = 1.23e-07
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop =  9, delta = 8.65e-07
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop =  9, delta = 4.00e-07
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop = 12, delta = -1.13e-08
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop =  9, delta = 9.78e-08
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop =  9, delta = 6.27e-08
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop =  6, delta = 2.95e-11
#
# sent message. HTTP Response:200
#
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop = 78, delta = 4.69e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# SCF loop converged.  Ne = 2.25, err < 1.0e-06, loop = 15, delta = 3.81e-01
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# SCF loop converged.  Ne = 2.50, err < 1.0e-06, loop = 72, delta = 2.93e-01
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# SCF loop converged.  Ne = 2.75, err < 1.0e-06, loop = 51, delta = 1.70e-01
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# SCF loop converged.  Ne = 3.00, err < 1.0e-06, loop = 60, delta = 2.33e-05
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 57, delta = 4.54e-05
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 42, delta = 2.01e-05
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 15, delta = 3.76e-04
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 18, delta = 2.31e-08
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 96, delta = 2.65e-01
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop = 27, delta = 3.91e-01
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 60, delta = 4.66e-01
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 21, delta = 5.14e-01
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop = 39, delta = 5.45e-01
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop = 33, delta = 5.64e-01
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 18, delta = 5.74e-01
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 18, delta = 5.77e-01
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 18, delta = 5.75e-01
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 30, delta = 5.69e-01
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# SCF loop converged.  Ne = 6.75, err < 1.0e-06, loop = 36, delta = 5.55e-01
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 18, delta = 5.27e-01
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop = 27, delta = 4.69e-01
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 57, delta = 3.28e-01
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 105, delta = 1.80e-01
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 36, delta = 6.94e-06
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop = 12, delta = 3.32e-04
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop = 18, delta = 5.96e-05
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop = 24, delta = 1.06e-04
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop =  9, delta = 1.88e-04
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop = 24, delta = 8.49e-05
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop =  9, delta = 9.92e-04
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop =  9, delta = 1.40e-05
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop =  9, delta = 6.25e-15
#
# sent message. HTTP Response:200
#
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop = 54, delta = 5.06e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# SCF loop converged.  Ne = 2.25, err < 1.0e-06, loop = 66, delta = 4.18e-01
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# SCF loop converged.  Ne = 2.50, err < 1.0e-06, loop = 18, delta = 3.28e-01
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# SCF loop converged.  Ne = 2.75, err < 1.0e-06, loop = 36, delta = 2.00e-01
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# SCF loop converged.  Ne = 3.00, err < 1.0e-06, loop = 33, delta = 1.68e-04
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 75, delta = 9.55e-05
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 15, delta = 3.06e-04
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 30, delta = 1.61e-04
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 18, delta = 1.47e-08
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 39, delta = 2.26e-01
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop = 24, delta = 3.50e-01
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 165, delta = 4.26e-01
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 21, delta = 4.76e-01
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop = 54, delta = 5.09e-01
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop = 51, delta = 5.29e-01
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 18, delta = 5.40e-01
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 18, delta = 5.43e-01
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 18, delta = 5.41e-01
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 15, delta = 5.33e-01
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# SCF loop converged.  Ne = 6.75, err < 1.0e-06, loop = 18, delta = 5.17e-01
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 51, delta = 4.90e-01
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop = 21, delta = 4.34e-01
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 39, delta = 2.97e-01
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 15, delta = 1.36e-01
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 15, delta = 9.31e-08
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop = 12, delta = 2.93e-09
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop =  9, delta = 2.00e-04
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop = 90, delta = 7.36e-05
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop = 12, delta = 1.64e-04
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop = 18, delta = 2.16e-04
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop =  9, delta = 1.10e-03
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop = 27, delta = 3.79e-05
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop =  9, delta = -3.24e-13
#
# sent message. HTTP Response:200
#
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop = 54, delta = 5.61e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# SCF loop converged.  Ne = 2.25, err < 1.0e-06, loop = 75, delta = 4.77e-01
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# SCF loop converged.  Ne = 2.50, err < 1.0e-06, loop = 45, delta = 3.84e-01
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# SCF loop converged.  Ne = 2.75, err < 1.0e-06, loop = 72, delta = 2.56e-01
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# SCF loop converged.  Ne = 3.00, err < 1.0e-06, loop = 99, delta = 2.29e-04
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 21, delta = 1.94e-04
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 30, delta = 7.11e-05
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 24, delta = 1.60e-04
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 30, delta = 3.90e-07
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 45, delta = 1.71e-01
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop = 21, delta = 2.85e-01
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 12, delta = 3.60e-01
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 15, delta = 4.11e-01
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop = 15, delta = 4.46e-01
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop = 33, delta = 4.69e-01
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 39, delta = 4.80e-01
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 18, delta = 4.83e-01
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 18, delta = 4.81e-01
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 24, delta = 4.73e-01
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# SCF loop converged.  Ne = 6.75, err < 1.0e-06, loop = 12, delta = 4.53e-01
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 27, delta = 4.15e-01
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop = 18, delta = 3.47e-01
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 48, delta = 2.25e-01
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 24, delta = 1.04e-01
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 27, delta = -6.15e-08
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop = 12, delta = 3.58e-08
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop = 12, delta = 4.38e-04
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop = 24, delta = 2.37e-04
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop = 15, delta = 8.67e-06
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop = 12, delta = 2.03e-04
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop = 186, delta = 1.11e-04
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop =  9, delta = 7.19e-04
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop =  9, delta = -2.05e-13
#
# sent message. HTTP Response:200
#
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop = 72, delta = 6.23e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# SCF loop converged.  Ne = 2.25, err < 1.0e-06, loop = 288, delta = 5.42e-01
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# SCF loop converged.  Ne = 2.50, err < 1.0e-06, loop = 24, delta = 4.52e-01
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# SCF loop converged.  Ne = 2.75, err < 1.0e-06, loop = 66, delta = 3.31e-01
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# SCF loop converged.  Ne = 3.00, err < 1.0e-06, loop = 63, delta = 2.74e-04
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 102, delta = 1.76e-04
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 24, delta = 1.71e-04
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 42, delta = 1.81e-04
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 36, delta = 1.46e-06
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 42, delta = 5.08e-06
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop =  9, delta = 2.06e-01
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 63, delta = 2.72e-01
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 18, delta = 3.21e-01
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop = 12, delta = 3.56e-01
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop = 30, delta = 3.79e-01
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 24, delta = 3.89e-01
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 21, delta = 3.91e-01
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 18, delta = 3.90e-01
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 18, delta = 3.83e-01
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# Calculation didn't converge. err > 1.0e-06, Ne = 6.75 loop = 1200, delta = 3.58e-01
# latter deltas are [0.26532074 0.31553238 0.33850139]
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 21, delta = 3.29e-01
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop = 42, delta = 2.69e-01
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 24, delta = 1.85e-01
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 39, delta = 8.88e-02
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 18, delta = 9.39e-07
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop = 15, delta = 5.70e-04
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop = 57, delta = 4.74e-04
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop = 96, delta = 7.82e-04
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop = 18, delta = 5.49e-04
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop = 18, delta = 9.50e-05
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop = 27, delta = 6.94e-04
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop = 27, delta = 1.55e-03
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop = 12, delta = 1.53e-10
#
# sent message. HTTP Response:200
#
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop = 27, delta = 6.81e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# SCF loop converged.  Ne = 2.25, err < 1.0e-06, loop = 36, delta = 6.04e-01
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# SCF loop converged.  Ne = 2.50, err < 1.0e-06, loop = 42, delta = 5.15e-01
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# SCF loop converged.  Ne = 2.75, err < 1.0e-06, loop = 81, delta = 4.03e-01
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# SCF loop converged.  Ne = 3.00, err < 1.0e-06, loop = 171, delta = 1.27e-03
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 48, delta = 1.72e-04
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 24, delta = 4.78e-04
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 45, delta = 7.20e-06
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 24, delta = 3.04e-08
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 18, delta = 6.28e-06
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop = 15, delta = 5.48e-04
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 33, delta = 2.19e-05
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 30, delta = 8.64e-04
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop =  9, delta = 2.26e-04
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop = 24, delta = 4.72e-05
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 72, delta = 8.17e-03
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 141, delta = 9.33e-02
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 27, delta = 2.61e-01
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 45, delta = 2.65e-01
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# SCF loop converged.  Ne = 6.75, err < 1.0e-06, loop = 12, delta = 2.52e-01
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 33, delta = 2.26e-01
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop =  6, delta = 1.85e-01
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 27, delta = 1.30e-01
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 63, delta = 6.53e-02
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 18, delta = 1.86e-08
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop = 12, delta = 6.23e-08
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop = 15, delta = 5.08e-05
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop = 21, delta = 3.61e-04
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop = 36, delta = 1.63e-06
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop = 36, delta = 7.71e-05
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop = 48, delta = 8.53e-04
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop = 69, delta = 2.53e-03
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop = 15, delta = 1.08e-03
#
# sent message. HTTP Response:200
#
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop = 21, delta = 7.28e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# SCF loop converged.  Ne = 2.25, err < 1.0e-06, loop = 15, delta = 6.53e-01
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# SCF loop converged.  Ne = 2.50, err < 1.0e-06, loop = 27, delta = 5.68e-01
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# SCF loop converged.  Ne = 2.75, err < 1.0e-06, loop = 57, delta = 4.63e-01
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# SCF loop converged.  Ne = 3.00, err < 1.0e-06, loop = 42, delta = 2.85e-01
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 150, delta = 7.28e-04
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 72, delta = 1.72e-04
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 39, delta = 2.71e-06
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 21, delta = 2.75e-06
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 18, delta = 3.19e-06
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop = 15, delta = 2.85e-04
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 15, delta = 1.70e-05
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 24, delta = 4.90e-04
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop = 30, delta = 3.15e-04
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop = 27, delta = 2.71e-05
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 42, delta = 3.57e-03
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 33, delta = 3.98e-05
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 15, delta = 2.97e-03
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 72, delta = 2.79e-04
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# SCF loop converged.  Ne = 6.75, err < 1.0e-06, loop = 24, delta = 3.54e-02
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 27, delta = 1.25e-01
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop =  9, delta = 1.03e-01
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 36, delta = 7.33e-02
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 30, delta = 3.75e-02
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 12, delta = 2.14e-07
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop = 21, delta = -2.22e-09
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop = 84, delta = 3.00e-04
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop = 51, delta = 3.31e-04
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop = 18, delta = 1.75e-04
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop = 21, delta = 4.27e-05
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop = 75, delta = 1.28e-03
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop = 27, delta = 6.05e-02
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop = 45, delta = 1.18e-01
#
# sent message. HTTP Response:200
#
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop = 15, delta = 7.60e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# SCF loop converged.  Ne = 2.25, err < 1.0e-06, loop = 69, delta = 6.86e-01
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# SCF loop converged.  Ne = 2.50, err < 1.0e-06, loop = 63, delta = 6.03e-01
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# SCF loop converged.  Ne = 2.75, err < 1.0e-06, loop = 36, delta = 5.06e-01
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# SCF loop converged.  Ne = 3.00, err < 1.0e-06, loop = 21, delta = 3.74e-01
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 141, delta = 1.15e-01
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 42, delta = 2.88e-04
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 21, delta = 3.22e-06
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 18, delta = -6.64e-09
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 18, delta = 6.64e-07
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop = 12, delta = 1.29e-04
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 24, delta = 1.13e-05
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 12, delta = 2.18e-04
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop = 18, delta = 3.51e-04
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop = 24, delta = 8.41e-06
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 18, delta = 1.54e-03
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 27, delta = 2.69e-06
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 24, delta = 1.19e-03
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 51, delta = 1.14e-04
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# SCF loop converged.  Ne = 6.75, err < 1.0e-06, loop = 12, delta = 8.67e-05
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 48, delta = 1.93e-03
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop = 60, delta = 1.43e-03
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 33, delta = 3.27e-02
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 18, delta = 1.73e-02
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 12, delta = 3.11e-08
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop = 18, delta = 3.52e-09
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop = 15, delta = 3.51e-05
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop = 24, delta = 1.24e-05
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop = 21, delta = 2.69e-04
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop = 186, delta = 3.98e-04
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop = 60, delta = 9.48e-02
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop = 129, delta = 1.95e-01
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop = 18, delta = 2.52e-01
#
# sent message. HTTP Response:200
#
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop = 15, delta = 7.79e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# SCF loop converged.  Ne = 2.25, err < 1.0e-06, loop = 60, delta = 7.05e-01
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# SCF loop converged.  Ne = 2.50, err < 1.0e-06, loop =  9, delta = 6.24e-01
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# SCF loop converged.  Ne = 2.75, err < 1.0e-06, loop = 33, delta = 5.33e-01
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# SCF loop converged.  Ne = 3.00, err < 1.0e-06, loop = 27, delta = 4.24e-01
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 105, delta = 2.80e-01
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 81, delta = 7.94e-02
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 39, delta = 1.43e-05
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 18, delta = -1.82e-08
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 18, delta = 3.73e-07
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop = 12, delta = 4.59e-05
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 18, delta = 1.29e-05
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 18, delta = 7.66e-05
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop = 15, delta = 2.30e-04
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop =  9, delta = 4.11e-05
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 12, delta = 6.07e-04
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 18, delta = 7.37e-07
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 12, delta = 1.01e-03
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 24, delta = 1.10e-04
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# SCF loop converged.  Ne = 6.75, err < 1.0e-06, loop = 24, delta = 9.23e-04
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 24, delta = 7.98e-04
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop = 12, delta = 6.26e-04
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 27, delta = 1.40e-03
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 15, delta = 2.01e-04
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 12, delta = 7.29e-09
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop = 18, delta = -5.83e-08
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop =  9, delta = 4.64e-05
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop = 27, delta = 5.90e-05
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop = 171, delta = 1.80e-03
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop = 81, delta = 1.70e-01
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop = 36, delta = 2.54e-01
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop = 51, delta = 3.12e-01
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop = 15, delta = 3.60e-01
#
# sent message. HTTP Response:200
#
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# SCF loop converged.  Ne = 2.00, err < 1.0e-06, loop = 12, delta = 7.85e-01
#
# SCF calculation start. Ne = 2.25, err < 1.0e-06
# SCF loop converged.  Ne = 2.25, err < 1.0e-06, loop = 129, delta = 7.12e-01
#
# SCF calculation start. Ne = 2.50, err < 1.0e-06
# SCF loop converged.  Ne = 2.50, err < 1.0e-06, loop = 57, delta = 6.33e-01
#
# SCF calculation start. Ne = 2.75, err < 1.0e-06
# SCF loop converged.  Ne = 2.75, err < 1.0e-06, loop = 72, delta = 5.46e-01
#
# SCF calculation start. Ne = 3.00, err < 1.0e-06
# SCF loop converged.  Ne = 3.00, err < 1.0e-06, loop = 105, delta = 4.49e-01
#
# SCF calculation start. Ne = 3.25, err < 1.0e-06
# SCF loop converged.  Ne = 3.25, err < 1.0e-06, loop = 60, delta = 3.40e-01
#
# SCF calculation start. Ne = 3.50, err < 1.0e-06
# SCF loop converged.  Ne = 3.50, err < 1.0e-06, loop = 78, delta = 2.12e-01
#
# SCF calculation start. Ne = 3.75, err < 1.0e-06
# SCF loop converged.  Ne = 3.75, err < 1.0e-06, loop = 81, delta = 8.30e-04
#
# SCF calculation start. Ne = 4.00, err < 1.0e-06
# SCF loop converged.  Ne = 4.00, err < 1.0e-06, loop = 15, delta = 4.36e-08
#
# SCF calculation start. Ne = 4.25, err < 1.0e-06
# SCF loop converged.  Ne = 4.25, err < 1.0e-06, loop = 12, delta = 2.27e-07
#
# SCF calculation start. Ne = 4.50, err < 1.0e-06
# SCF loop converged.  Ne = 4.50, err < 1.0e-06, loop = 12, delta = 1.03e-05
#
# SCF calculation start. Ne = 4.75, err < 1.0e-06
# SCF loop converged.  Ne = 4.75, err < 1.0e-06, loop = 12, delta = 1.21e-05
#
# SCF calculation start. Ne = 5.00, err < 1.0e-06
# SCF loop converged.  Ne = 5.00, err < 1.0e-06, loop = 12, delta = 2.56e-05
#
# SCF calculation start. Ne = 5.25, err < 1.0e-06
# SCF loop converged.  Ne = 5.25, err < 1.0e-06, loop = 12, delta = 5.37e-05
#
# SCF calculation start. Ne = 5.50, err < 1.0e-06
# SCF loop converged.  Ne = 5.50, err < 1.0e-06, loop = 12, delta = 2.55e-05
#
# SCF calculation start. Ne = 5.75, err < 1.0e-06
# SCF loop converged.  Ne = 5.75, err < 1.0e-06, loop = 21, delta = 1.34e-04
#
# SCF calculation start. Ne = 6.00, err < 1.0e-06
# SCF loop converged.  Ne = 6.00, err < 1.0e-06, loop = 12, delta = 2.62e-07
#
# SCF calculation start. Ne = 6.25, err < 1.0e-06
# SCF loop converged.  Ne = 6.25, err < 1.0e-06, loop = 12, delta = 2.02e-04
#
# SCF calculation start. Ne = 6.50, err < 1.0e-06
# SCF loop converged.  Ne = 6.50, err < 1.0e-06, loop = 24, delta = 5.95e-05
#
# SCF calculation start. Ne = 6.75, err < 1.0e-06
# SCF loop converged.  Ne = 6.75, err < 1.0e-06, loop = 12, delta = 1.86e-04
#
# SCF calculation start. Ne = 7.00, err < 1.0e-06
# SCF loop converged.  Ne = 7.00, err < 1.0e-06, loop = 27, delta = 1.60e-04
#
# SCF calculation start. Ne = 7.25, err < 1.0e-06
# SCF loop converged.  Ne = 7.25, err < 1.0e-06, loop = 18, delta = 1.26e-04
#
# SCF calculation start. Ne = 7.50, err < 1.0e-06
# SCF loop converged.  Ne = 7.50, err < 1.0e-06, loop = 27, delta = 2.82e-04
#
# SCF calculation start. Ne = 7.75, err < 1.0e-06
# SCF loop converged.  Ne = 7.75, err < 1.0e-06, loop = 30, delta = 3.85e-05
#
# SCF calculation start. Ne = 8.00, err < 1.0e-06
# SCF loop converged.  Ne = 8.00, err < 1.0e-06, loop = 12, delta = 2.74e-09
#
# SCF calculation start. Ne = 8.25, err < 1.0e-06
# SCF loop converged.  Ne = 8.25, err < 1.0e-06, loop = 27, delta = 2.09e-06
#
# SCF calculation start. Ne = 8.50, err < 1.0e-06
# SCF loop converged.  Ne = 8.50, err < 1.0e-06, loop = 84, delta = 1.16e-03
#
# SCF calculation start. Ne = 8.75, err < 1.0e-06
# SCF loop converged.  Ne = 8.75, err < 1.0e-06, loop = 30, delta = 1.34e-01
#
# SCF calculation start. Ne = 9.00, err < 1.0e-06
# SCF loop converged.  Ne = 9.00, err < 1.0e-06, loop = 27, delta = 2.09e-01
#
# SCF calculation start. Ne = 9.25, err < 1.0e-06
# SCF loop converged.  Ne = 9.25, err < 1.0e-06, loop = 48, delta = 2.69e-01
#
# SCF calculation start. Ne = 9.50, err < 1.0e-06
# SCF loop converged.  Ne = 9.50, err < 1.0e-06, loop = 15, delta = 3.22e-01
#
# SCF calculation start. Ne = 9.75, err < 1.0e-06
# SCF loop converged.  Ne = 9.75, err < 1.0e-06, loop =  9, delta = 3.70e-01
#
# SCF calculation start. Ne = 10.00, err < 1.0e-06
# SCF loop converged.  Ne = 10.00, err < 1.0e-06, loop = 12, delta = 4.14e-01
#
# sent message. HTTP Response:200
#
# SCF calculation start. Ne = 2.00, err < 1.0e-06
# e:\Documents\codes\TUS\B3\レポート\2024_11_28_AlterMagnet2\lib\funcs.py:280: RuntimeWarning: invalid value encountered in divide
#   # 収束すると分母が0になり発散するため例外処理が必要
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 7
#       5 for Np in Nps:
#       6     model = fs.CuO2(Ne = Np, a = _a, k_mesh = 51)
# ----> 7     model.calc_scf()
#       8     deltas = np.append(deltas, model.delta)
#       9 path = make_delta_graph(Nps, deltas, _a)
#
# File e:\Documents\codes\TUS\B3\レポート\2024_11_28_AlterMagnet2\lib\funcs.py:388, in CuO2.calc_scf(self, iteration, err)
#     386 for i in range(self.k_mesh):
#     387     for j in range(self.k_mesh):
# --> 388         eigenEnergy, eigenState = Hamiltonian(kx[i][j],ky[i][j],self.a, Delta )
#     389         enes = np.append(enes, eigenEnergy)
#     390         eigenEnes[i,j] = eigenEnergy
#
# File e:\Documents\codes\TUS\B3\レポート\2024_11_28_AlterMagnet2\lib\funcs.py:134, in Hamiltonian(kx, ky, a0, delta)
#     131 H[0+n_orbit,0+n_orbit] = Ud * delta /2
#     132 H[1+n_orbit,1+n_orbit] = -Ud * delta /2
# --> 134 return scipy.linalg.eigh(H)
#
# File c:\Users\xiang\.conda\envs\py3-11-9\Lib\site-packages\scipy\_lib\deprecation.py:213, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     211 extra_args = len(args) - len(all_args)
#     212 if extra_args <= 0:
# --> 213     return f(*args, **kwargs)
#     215 # extra_args > 0
#     216 args_msg = [
#     217     f"{name}={arg}"
#     218     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#     219 ]
#
# File c:\Users\xiang\.conda\envs\py3-11-9\Lib\site-packages\scipy\linalg\_decomp.py:464, in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite, subset_by_index, subset_by_value, driver)
#     460 if driver not in drv_str:
#     461     raise ValueError('"{}" is unknown. Possible values are "None", "{}".'
#     462                      ''.format(driver, '", "'.join(drv_str[1:])))
# --> 464 a1 = _asarray_validated(a, check_finite=check_finite)
#     465 if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     466     raise ValueError('expected square "a" matrix')
#
# File c:\Users\xiang\.conda\envs\py3-11-9\Lib\site-packages\scipy\_lib\_util.py:321, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     319         raise ValueError('masked arrays are not supported')
#     320 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 321 a = toarray(a)
#     322 if not objects_ok:
#     323     if a.dtype is np.dtype('O'):
#
# File c:\Users\xiang\.conda\envs\py3-11-9\Lib\site-packages\numpy\lib\function_base.py:630, in asarray_chkfinite(a, dtype, order)
#     628 a = asarray(a, dtype=dtype, order=order)
#     629 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 630     raise ValueError(
#     631         "array must not contain infs or NaNs")
#     632 return a
#
# ValueError: array must not contain infs or NaNs
